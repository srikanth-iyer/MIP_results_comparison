# %%
import pandas as pd
import geopandas as gpd
import altair as alt

from pathlib import Path

cwd = Path.cwd()

# %%
all_cap = pd.read_parquet(cwd / "all" / "capacity.parquet")
all_cap.head()
# Out:
#                             resource_name  zone   tech_type model  \
# 312737                   BASN_batteries_1  BASN     Battery  GenX
# 312738  BASN_conventional_hydroelectric_1  BASN       Hydro  GenX
# 312739     BASN_conventional_steam_coal_1  BASN        Coal  GenX
# 312740     BASN_conventional_steam_coal_2  BASN        Coal  GenX
# 312741                  BASN_geothermal_1  BASN  Geothermal  GenX
#
#         planning_year               case unit  start_value  end_value  \
# 312737           2027  20-week-foresight   MW        936.0      936.0
# 312738           2027  20-week-foresight   MW       2490.0     2490.0
# 312739           2027  20-week-foresight   MW       1178.0     1178.0
# 312740           2027  20-week-foresight   MW       1822.0     1822.0
# 312741           2027  20-week-foresight   MW        462.0      462.0
#
#         start_MWh  end_MWh  existing  new_build agg_zone
# 312737        NaN      NaN      True      False     WECC
# 312738        NaN      NaN      True      False     WECC
# 312739        NaN      NaN      True      False     WECC
# 312740        NaN      NaN      True      False     WECC
# 312741        NaN      NaN      True      False     WECC

# %%
all_cap_range = (
    all_cap.query("case=='full-base-200' and new_build == True")
    .groupby(["model", "planning_year", "tech_type"])["end_value"]
    .sum()
    .groupby(["planning_year", "tech_type"])
    .agg(["min", "mean", "max"])
    .reset_index()
)
all_cap_range["relative_difference"] = (all_cap_range["max"] - all_cap_range["min"]) / all_cap_range["mean"]
all_cap_range
# Out:
#     planning_year       tech_type       min           mean       max  \
# 0            2027         Battery      29.0      29.000000      29.0
# 1            2027             CCS       0.0       0.000000       0.0
# 2            2027        Hydrogen       1.0       1.000000       1.0
# 3            2027  Natural Gas CC      21.0    1423.750000    4970.0
# 4            2027  Natural Gas CT      13.0      13.000000      13.0
# 5            2027         Nuclear       0.0       0.000000       0.0
# 6            2027           Solar      75.0     105.500000     136.0
# 7            2027            Wind  115266.0  117741.500000  121794.0
# 8            2030         Battery     600.0     600.000000     600.0
# 9            2030             CCS   71961.0   74693.250000   77473.0
# 10           2030        Hydrogen     310.0     310.000000     310.0
# 11           2030  Natural Gas CC    1027.0    2490.500000    4970.0
# 12           2030  Natural Gas CT     168.0     168.000000     168.0
# 13           2030         Nuclear      69.0      69.000000      69.0
# 14           2030           Solar  242498.0  247862.500000  251402.0
# 15           2030            Wind  350872.0  360331.500000  369327.0
# 16           2035         Battery    2802.0    3177.750000    3544.0
# 17           2035             CCS  173043.0  177512.500000  181546.0
# 18           2035        Hydrogen       0.0      56.666667     145.0
# 19           2035  Natural Gas CC    9212.0   11227.000000   15089.0
# 20           2035  Natural Gas CT       0.0      21.500000      70.0
# 21           2035         Nuclear       0.0      35.500000      71.0
# 22           2035           Solar  384808.0  391145.750000  395884.0
# 23           2035            Wind  421434.0  432707.750000  448523.0
# 24           2040         Battery   11286.0   16551.250000   20786.0
# 25           2040             CCS  231026.0  236232.500000  238712.0
# 26           2040        Hydrogen       0.0      72.333333     167.0
# 27           2040  Natural Gas CC   10340.0   13611.000000   18944.0
# 28           2040  Natural Gas CT       0.0     727.000000    2806.0
# 29           2040         Nuclear       0.0      37.500000      75.0
# 30           2040           Solar  489281.0  500689.500000  505404.0
# 31           2040            Wind  481513.0  495896.250000  514921.0
# 32           2045         Battery   34982.0   47997.750000   55553.0
# 33           2045             CCS  285199.0  292187.250000  295233.0
# 34           2045        Hydrogen       0.0      82.333333     180.0
# 35           2045  Natural Gas CC   11369.0   14866.500000   20004.0
# 36           2045  Natural Gas CT       0.0     731.000000    2806.0
# 37           2045         Nuclear       0.0      38.500000      77.0
# 38           2045           Solar  624342.0  641983.750000  650902.0
# 39           2045            Wind  552433.0  568849.750000  594061.0
# 40           2050         Battery  106428.0  122255.500000  128686.0
# 41           2050             CCS  311403.0  319288.500000  324747.0
# 42           2050        Hydrogen       0.0      83.666667     194.0
# 43           2050  Natural Gas CC   11380.0   14873.000000   20004.0
# 44           2050  Natural Gas CT       0.0     731.750000    2806.0
# 45           2050         Nuclear       0.0      40.000000      80.0
# 46           2050           Solar  773625.0  795434.250000  805755.0
# 47           2050            Wind  594720.0  610281.500000  634543.0
#
#     relative_difference
# 0              0.000000
# 1                   NaN
# 2              0.000000
# 3              3.476032
# 4              0.000000
# 5                   NaN
# 6              0.578199
# 7              0.055443
# 8              0.000000
# 9              0.073795
# 10             0.000000
# 11             1.583216
# 12             0.000000
# 13             0.000000
# 14             0.035923
# 15             0.051217
# 16             0.233499
# 17             0.047901
# 18             2.558824
# 19             0.523470
# 20             3.255814
# 21             2.000000
# 22             0.028317
# 23             0.062603
# 24             0.573975
# 25             0.032536
# 26             2.308756
# 27             0.632136
# 28             3.859697
# 29             2.000000
# 30             0.032202
# 31             0.067369
# 32             0.428583
# 33             0.034341
# 34             2.186235
# 35             0.580836
# 36             3.838577
# 37             2.000000
# 38             0.041372
# 39             0.073179
# 40             0.182061
# 41             0.041793
# 42             2.318725
# 43             0.579843
# 44             3.834643
# 45             2.000000
# 46             0.040393
# 47             0.065253

# %%
all_cap_range.query("tech_type in ['Hydrogen', 'Geothermal']")
# Out:
#     planning_year   tech_type    min        mean    max  relative_difference
# 4            2027  Geothermal  676.0  713.250000  825.0             0.208903
# 6            2027    Hydrogen    1.0    1.000000    1.0             0.000000
# 16           2030  Geothermal  620.0  654.000000  754.0             0.204893
# 18           2030    Hydrogen  310.0  310.000000  310.0             0.000000
# 28           2035  Geothermal  591.0  622.500000  717.0             0.202410
# 30           2035    Hydrogen    0.0   56.666667  145.0             2.558824
# 40           2040  Geothermal  390.0  396.000000  398.0             0.020202
# 42           2040    Hydrogen    0.0   72.333333  167.0             2.308756
# 52           2045  Geothermal  217.0  219.500000  227.0             0.045558
# 54           2045    Hydrogen    0.0   82.333333  180.0             2.186235
# 64           2050  Geothermal   45.0   86.250000  100.0             0.637681
# 66           2050    Hydrogen    0.0   83.666667  194.0             2.318725

# %%
all_cap_range.query("tech_type not in ['Geothermal', 'Distributed Solar','Hydrogen']").dropna()
# Out:
#     planning_year       tech_type       min       mean       max  \
# 0            2027         Battery      29.0      29.00      29.0
# 3            2027  Natural Gas CC      21.0    1423.75    4970.0
# 4            2027  Natural Gas CT      13.0      13.00      13.0
# 6            2027           Solar      75.0     105.50     136.0
# 7            2027            Wind  115266.0  117741.50  121794.0
# 8            2030         Battery     600.0     600.00     600.0
# 9            2030             CCS   71961.0   74693.25   77473.0
# 11           2030  Natural Gas CC    1027.0    2490.50    4970.0
# 12           2030  Natural Gas CT     168.0     168.00     168.0
# 13           2030         Nuclear      69.0      69.00      69.0
# 14           2030           Solar  242498.0  247862.50  251402.0
# 15           2030            Wind  350872.0  360331.50  369327.0
# 16           2035         Battery    2802.0    3177.75    3544.0
# 17           2035             CCS  173043.0  177512.50  181546.0
# 19           2035  Natural Gas CC    9212.0   11227.00   15089.0
# 20           2035  Natural Gas CT       0.0      21.50      70.0
# 21           2035         Nuclear       0.0      35.50      71.0
# 22           2035           Solar  384808.0  391145.75  395884.0
# 23           2035            Wind  421434.0  432707.75  448523.0
# 24           2040         Battery   11286.0   16551.25   20786.0
# 25           2040             CCS  231026.0  236232.50  238712.0
# 27           2040  Natural Gas CC   10340.0   13611.00   18944.0
# 28           2040  Natural Gas CT       0.0     727.00    2806.0
# 29           2040         Nuclear       0.0      37.50      75.0
# 30           2040           Solar  489281.0  500689.50  505404.0
# 31           2040            Wind  481513.0  495896.25  514921.0
# 32           2045         Battery   34982.0   47997.75   55553.0
# 33           2045             CCS  285199.0  292187.25  295233.0
# 35           2045  Natural Gas CC   11369.0   14866.50   20004.0
# 36           2045  Natural Gas CT       0.0     731.00    2806.0
# 37           2045         Nuclear       0.0      38.50      77.0
# 38           2045           Solar  624342.0  641983.75  650902.0
# 39           2045            Wind  552433.0  568849.75  594061.0
# 40           2050         Battery  106428.0  122255.50  128686.0
# 41           2050             CCS  311403.0  319288.50  324747.0
# 43           2050  Natural Gas CC   11380.0   14873.00   20004.0
# 44           2050  Natural Gas CT       0.0     731.75    2806.0
# 45           2050         Nuclear       0.0      40.00      80.0
# 46           2050           Solar  773625.0  795434.25  805755.0
# 47           2050            Wind  594720.0  610281.50  634543.0
#
#     relative_difference
# 0              0.000000
# 3              3.476032
# 4              0.000000
# 6              0.578199
# 7              0.055443
# 8              0.000000
# 9              0.073795
# 11             1.583216
# 12             0.000000
# 13             0.000000
# 14             0.035923
# 15             0.051217
# 16             0.233499
# 17             0.047901
# 19             0.523470
# 20             3.255814
# 21             2.000000
# 22             0.028317
# 23             0.062603
# 24             0.573975
# 25             0.032536
# 27             0.632136
# 28             3.859697
# 29             2.000000
# 30             0.032202
# 31             0.067369
# 32             0.428583
# 33             0.034341
# 35             0.580836
# 36             3.838577
# 37             2.000000
# 38             0.041372
# 39             0.073179
# 40             0.182061
# 41             0.041793
# 43             0.579843
# 44             3.834643
# 45             2.000000
# 46             0.040393
# 47             0.065253

# %%
data = all_cap_range.query("planning_year in [2030, 2050] and relative_difference > 0").dropna()
data["mean"] /= 1000
# data["relative_difference"] = data["relative_difference"].replace(0, np.nan).dropna()
alt.Chart(
    # all_cap_range.query("tech_type not in ['Geothermal', 'Distributed Solar','Hydrogen']").dropna()
    data
    ).mark_point().encode(
    x=alt.X("mean").title("New Capacity (GW)"), # .scale(type="log"),
    y=alt.Y("relative_difference").scale(type="log").title("Relative Difference"),
    color=alt.Color("tech_type").title("Technology"),
    shape="tech_type",
    tooltip=["tech_type", "relative_difference", "mean", "planning_year"],
    
).properties(
    height=200,
    width=200
).facet(
    facet=alt.Facet("planning_year").title("Planning Year"),
    columns=2
)
# Out:
# alt.FacetChart(...)

# %%
all_tx = pd.read_csv(cwd / "all" / "annual_tx_expansion.csv")

# %%
all_tx.query("line_name == 'SRSG_to_TRE' and case == 'full-base-200'")
# Out:
#         model    line_name  planning_year           case unit   value  \
# 5434     GenX  SRSG_to_TRE           2023  full-base-200   MW     0.0
# 5491     GenX  SRSG_to_TRE           2027  full-base-200   MW     2.0
# 5548     GenX  SRSG_to_TRE           2030  full-base-200   MW  2453.0
# 5605     GenX  SRSG_to_TRE           2035  full-base-200   MW  1003.0
# 5662     GenX  SRSG_to_TRE           2040  full-base-200   MW  1085.0
# 5719     GenX  SRSG_to_TRE           2045  full-base-200   MW  1297.0
# 5776     GenX  SRSG_to_TRE           2050  full-base-200   MW     0.0
# 5833   SWITCH  SRSG_to_TRE           2023  full-base-200   MW     0.0
# 5890   SWITCH  SRSG_to_TRE           2027  full-base-200   MW     0.0
# 5947   SWITCH  SRSG_to_TRE           2030  full-base-200   MW  1540.0
# 6004   SWITCH  SRSG_to_TRE           2035  full-base-200   MW   985.0
# 6061   SWITCH  SRSG_to_TRE           2040  full-base-200   MW   909.0
# 6118   SWITCH  SRSG_to_TRE           2045  full-base-200   MW   778.0
# 6175   SWITCH  SRSG_to_TRE           2050  full-base-200   MW     0.0
# 6263    TEMOA  SRSG_to_TRE           2030  full-base-200   MW  2379.0
# 6311    TEMOA  SRSG_to_TRE           2035  full-base-200   MW  1175.0
# 6349    TEMOA  SRSG_to_TRE           2040  full-base-200   MW  1054.0
# 6390    TEMOA  SRSG_to_TRE           2045  full-base-200   MW  1539.0
# 6427    TEMOA  SRSG_to_TRE           2050  full-base-200   MW    58.0
# 6507  USENSYS  SRSG_to_TRE           2030  full-base-200   MW  1609.0
# 6530  USENSYS  SRSG_to_TRE           2035  full-base-200   MW   869.0
# 6549  USENSYS  SRSG_to_TRE           2040  full-base-200   MW  2582.0
# 6571  USENSYS  SRSG_to_TRE           2045  full-base-200   MW  2204.0
# 6582  USENSYS  SRSG_to_TRE           2050  full-base-200   MW  1485.0
#
#       end_value  line start_region dest_region
# 5434        2.0  57.0         SRSG         TRE
# 5491        NaN  57.0         SRSG         TRE
# 5548        NaN  57.0         SRSG         TRE
# 5605        NaN  57.0         SRSG         TRE
# 5662        NaN  57.0         SRSG         TRE
# 5719        NaN  57.0         SRSG         TRE
# 5776        NaN  57.0         SRSG         TRE
# 5833        0.0   NaN         SRSG         TRE
# 5890        NaN   NaN         SRSG         TRE
# 5947        NaN   NaN         SRSG         TRE
# 6004        NaN   NaN         SRSG         TRE
# 6061        NaN   NaN         SRSG         TRE
# 6118        NaN   NaN         SRSG         TRE
# 6175        NaN   NaN         SRSG         TRE
# 6263        NaN  57.0         SRSG         TRE
# 6311        NaN  57.0         SRSG         TRE
# 6349        NaN  57.0         SRSG         TRE
# 6390        NaN  57.0         SRSG         TRE
# 6427        NaN  57.0         SRSG         TRE
# 6507        NaN   NaN         SRSG         TRE
# 6530        NaN   NaN         SRSG         TRE
# 6549        NaN   NaN         SRSG         TRE
# 6571        NaN   NaN         SRSG         TRE
# 6582        NaN   NaN         SRSG         TRE

# %%
base_total_tx_exp = (
    all_tx.query("case == 'full-base-200'")
    .groupby(["line_name", "start_region", "dest_region", "model"], as_index=False)[
        "value"
    ]
    .sum()
)
base_total_tx_exp
# Out:
#         line_name start_region dest_region    model    value
# 0    BASN_to_CANO         BASN        CANO     GenX    102.0
# 1    BASN_to_CANO         BASN        CANO   SWITCH    100.0
# 2    BASN_to_CANO         BASN        CANO    TEMOA    111.0
# 3    BASN_to_CANO         BASN        CANO  USENSYS    100.0
# 4    BASN_to_CASO         BASN        CASO     GenX   5920.0
# ..            ...          ...         ...      ...      ...
# 240   TREW_to_TRE         TREW         TRE    TEMOA     11.0
# 241   TRE_to_TREW          TRE        TREW     GenX  16529.0
# 242   TRE_to_TREW          TRE        TREW   SWITCH  16529.0
# 243   TRE_to_TREW          TRE        TREW    TEMOA  16529.0
# 244   TRE_to_TREW          TRE        TREW  USENSYS  16529.0
#
# [245 rows x 5 columns]

# %%
base_tx_exp_range = base_total_tx_exp.groupby(
    ["line_name", "start_region", "dest_region"], as_index=False
)["value"].agg(["min", "mean", "max"])
base_tx_exp_range["relative_difference"] = (
    base_tx_exp_range["max"] - base_tx_exp_range["min"]
) / base_tx_exp_range["mean"]
base_tx_exp_range
# Out:
#        line_name start_region dest_region      min      mean      max  \
# 0   BASN_to_CANO         BASN        CANO    100.0    103.25    111.0
# 1   BASN_to_CASO         BASN        CASO   5920.0   5920.00   5920.0
# 2   BASN_to_NWPP         BASN        NWPP   3350.0   3350.00   3350.0
# 3   BASN_to_RMRG         BASN        RMRG   5518.0   5668.00   5835.0
# 4   BASN_to_SRSG         BASN        SRSG   5385.0   5385.00   5385.0
# ..           ...          ...         ...      ...       ...      ...
# 60  SRCE_to_SRSE         SRCE        SRSE   3196.0   3216.75   3275.0
# 61  SRSG_to_BASN         SRSG        BASN      0.0      1.00      2.0
# 62   SRSG_to_TRE         SRSG         TRE   4212.0   6251.50   8749.0
# 63   TREW_to_TRE         TREW         TRE      0.0      4.00     11.0
# 64   TRE_to_TREW          TRE        TREW  16529.0  16529.00  16529.0
#
#     relative_difference
# 0              0.106538
# 1              0.000000
# 2              0.000000
# 3              0.055928
# 4              0.000000
# ..                  ...
# 60             0.024559
# 61             2.000000
# 62             0.725746
# 63             2.750000
# 64             0.000000
#
# [65 rows x 7 columns]

# %%
base_tx_exp_range.sort_values("relative_difference").tail(10)
# Out:
#        line_name start_region dest_region    min    mean    max  \
# 58  SRCA_to_SRCE         SRCA        SRCE  216.0  440.75  588.0
# 32  MISW_to_SPPC         MISW        SPPC  100.0  253.50  542.0
# 8   CASO_to_CANO         CASO        CANO    0.0    3.00    6.0
# 7   CASO_to_BASN         CASO        BASN    0.0    1.00    2.0
# 61  SRSG_to_BASN         SRSG        BASN    0.0    1.00    2.0
# 34  NWPP_to_BASN         NWPP        BASN    0.0    1.00    2.0
# 46  PJMW_to_MISE         PJMW        MISE    0.0    0.50    1.0
# 63   TREW_to_TRE         TREW         TRE    0.0    4.00   11.0
# 29  MISW_to_MISC         MISW        MISC    0.0    0.00    0.0
# 35  NWPP_to_CASO         NWPP        CASO    0.0    0.00    0.0
#
#     relative_difference
# 58             0.844016
# 32             1.743590
# 8              2.000000
# 7              2.000000
# 61             2.000000
# 34             2.000000
# 46             2.000000
# 63             2.750000
# 29                  NaN
# 35                  NaN

# %%
base_tx_exp_range.sort_values("mean")
# Out:
#        line_name start_region dest_region      min      mean      max  \
# 35  NWPP_to_CASO         NWPP        CASO      0.0      0.00      0.0
# 29  MISW_to_MISC         MISW        MISC      0.0      0.00      0.0
# 46  PJMW_to_MISE         PJMW        MISE      0.0      0.50      1.0
# 61  SRSG_to_BASN         SRSG        BASN      0.0      1.00      2.0
# 34  NWPP_to_BASN         NWPP        BASN      0.0      1.00      2.0
# ..           ...          ...         ...      ...       ...      ...
# 18  MISC_to_PJMW         MISC        PJMW  10927.0  12454.25  14071.0
# 55  SPPS_to_SRSG         SPPS        SRSG  10101.0  14181.25  16181.0
# 64   TRE_to_TREW          TRE        TREW  16529.0  16529.00  16529.0
# 26  MISS_to_SPPS         MISS        SPPS  16970.0  22965.50  26104.0
# 45  PJME_to_PJMW         PJME        PJMW  38851.0  47536.25  52698.0
#
#     relative_difference       lat1        lon1       lat2        lon2
# 35                  NaN  45.925635 -117.047147  35.083692 -117.407157
# 29                  NaN  45.702637  -95.996143  39.075295  -89.537578
# 46             2.000000  39.422340  -81.908171  43.569687  -84.579049
# 61             2.000000  34.357403 -109.333542  40.570631 -114.459232
# 34             2.000000  45.925635 -117.047147  40.570631 -114.459232
# ..                  ...        ...         ...        ...         ...
# 18             0.252444  39.075295  -89.537578  39.422340  -81.908171
# 55             0.428735  34.990645  -98.457473  34.357403 -109.333542
# 64             0.000000  30.318114  -97.544556  32.161745 -101.589682
# 26             0.397727  32.374053  -91.562627  34.990645  -98.457473
# 45             0.291293  40.365650  -76.720576  39.422340  -81.908171
#
# [65 rows x 11 columns]

# %%
gdf = gpd.read_file("conus_26z_latlon_simple.geojson")
gdf = gdf.rename(columns={"model_region": "zone"})

# %%
geoshape_kwargs = {
        "stroke": "white",
        "fill": "silver",
    }
gdf["lat"] = gdf.geometry.centroid.y
gdf["lon"] = gdf.geometry.centroid.x
base_tx_exp_range["lat1"] = base_tx_exp_range["start_region"].map(gdf.set_index("zone")["lat"])
base_tx_exp_range["lon1"] = base_tx_exp_range["start_region"].map(gdf.set_index("zone")["lon"])
base_tx_exp_range["lat2"] = base_tx_exp_range["dest_region"].map(gdf.set_index("zone")["lat"])
base_tx_exp_range["lon2"] = base_tx_exp_range["dest_region"].map(gdf.set_index("zone")["lon"])

background = (
            alt.Chart(gdf)
            .mark_geoshape(**geoshape_kwargs)
            .project(type="albersUsa")
            .properties(height=325, width=400)
        )
lines = alt.Chart(
    base_tx_exp_range.query("mean > 500")
    ).mark_rule().encode(
    latitude="lat1",
    longitude="lon1",
    latitude2="lat2",
    longitude2="lon2",
    strokeWidth=alt.StrokeWidth("mean").title("Average Expansion (MW)"), #.scale(type="log"),
    color=alt.Color("relative_difference:Q")
    .scale(scheme="magma", reverse=True)
    .title("Model Difference"),
    tooltip=["line_name", "min", "mean", "max", "relative_difference"]
).project(type="albersUsa")

background + lines
# Out:
# /var/folders/nr/y3csklpd0l77v_k39y46s2rc0000gn/T/ipykernel_61113/884558716.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["lat"] = gdf.geometry.centroid.y
# /var/folders/nr/y3csklpd0l77v_k39y46s2rc0000gn/T/ipykernel_61113/884558716.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["lon"] = gdf.geometry.centroid.x
# alt.LayerChart(...)

# %%
geoshape_kwargs = {
        "stroke": "white",
        "fill": "silver",
    }
gdf["lat"] = gdf.geometry.centroid.y
gdf["lon"] = gdf.geometry.centroid.x
base_tx_exp_range["lat1"] = base_tx_exp_range["start_region"].map(gdf.set_index("zone")["lat"])
base_tx_exp_range["lon1"] = base_tx_exp_range["start_region"].map(gdf.set_index("zone")["lon"])
base_tx_exp_range["lat2"] = base_tx_exp_range["dest_region"].map(gdf.set_index("zone")["lat"])
base_tx_exp_range["lon2"] = base_tx_exp_range["dest_region"].map(gdf.set_index("zone")["lon"])

background = (
            alt.Chart(gdf)
            .mark_geoshape(**geoshape_kwargs)
            .project(type="albersUsa")
            .properties(height=325, width=400)
        )
lines = alt.Chart(
    base_tx_exp_range.query("mean > 500")
    ).mark_rule().encode(
    latitude="lat1",
    longitude="lon1",
    latitude2="lat2",
    longitude2="lon2",
    strokeWidth=alt.StrokeWidth("mean").title("Average Expansion (MW)").scale(type="log"),
    color=alt.Color("relative_difference:Q")
    .scale(scheme="magma", reverse=True)
    .title("Model Difference"),
    tooltip=["line_name", "min", "mean", "max", "relative_difference"]
).project(type="albersUsa")

background + lines
# Out:
# /var/folders/nr/y3csklpd0l77v_k39y46s2rc0000gn/T/ipykernel_61113/4081479056.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["lat"] = gdf.geometry.centroid.y
# /var/folders/nr/y3csklpd0l77v_k39y46s2rc0000gn/T/ipykernel_61113/4081479056.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf["lon"] = gdf.geometry.centroid.x
# alt.LayerChart(...)

# %%
alt.Chart(
    base_tx_exp_range.query("mean > 500")
    ).mark_point().encode(
    x=alt.X("mean").title("Capacity (MW)"), #.scale(type="log"),
    y=alt.Y("relative_difference"), #.scale(type="log"),
    # color="tech_type",
    # shape="tech_type",
    # tooltip=["tech_type", "relative_difference", "mean", "planning_year"],
    
).properties(
    height=200,
    width=400
)
# Out:
# alt.Chart(...)

# %%
alt.Chart()
